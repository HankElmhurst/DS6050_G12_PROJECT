# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# 1. Load the data
df = pd.read_csv('../results/all_experiments.csv')

# %% [markdown]
# # 1. Optimal Params for SimpleCNN

# %%
df[(df["experiment_name"].str.contains("dropout")) | (df["experiment_name"] == "baseline_simple_cnn")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp       experiment_name  model_type optimizer  \
# 24  2026-04-21T02:39:46.683263   baseline_simple_cnn  simple_cnn     adamw
# 9   2026-04-21T02:09:24.965559   ablation_dropout_04  simple_cnn     adamw
# 8   2026-04-21T02:06:59.055394  ablation_dropout_025  simple_cnn     adamw
# 7   2026-04-21T02:04:26.225567   ablation_dropout_00  simple_cnn     adamw
# 11  2026-04-21T02:11:54.936376   ablation_dropout_05  simple_cnn     adamw
#
#        lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 24  0.001         128     0.30         none             he    0.9191  ...
# 9   0.001         128     0.40         none             he    0.9171  ...
# 8   0.001         128     0.25         none             he    0.9117  ...
# 7   0.001         128     0.00         none             he    0.9114  ...
# 11  0.001         128     0.50         none             he    0.9108  ...
#
#     epochs_run best_epoch  num_params    flops  gpu_mem_mb  \
# 24          30         26      207018  1293312        50.1
# 9           28         23      207018  1293312        50.1
# 8           28         23      207018  1293312        50.1
# 7           24         19      207018  1293312        50.1
# 11          30         25      207018  1293312        50.1
#
#                    device  seed                config_file slurm_job_id   N
# 24  NVIDIA A100-SXM4-80GB    42   baseline_simple_cnn.yaml     11980596 NaN
# 9   NVIDIA A100-SXM4-80GB    42   ablation_dropout_04.yaml     11980581 NaN
# 8   NVIDIA A100-SXM4-80GB    42  ablation_dropout_025.yaml     11980580 NaN
# 7   NVIDIA A100-SXM4-80GB    42   ablation_dropout_00.yaml     11980579 NaN
# 11  NVIDIA A100-SXM4-80GB    42   ablation_dropout_05.yaml     11980582 NaN
#
# [5 rows x 23 columns]

# %%
df[df["experiment_name"].str.contains("lr")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp    experiment_name  model_type optimizer  \
# 14  2026-04-21T02:16:20.046640   ablation_lr_0001  simple_cnn     adamw
# 16  2026-04-21T02:17:47.031383    ablation_lr_001  simple_cnn     adamw
# 15  2026-04-21T02:17:30.486231  ablation_lr_00001  simple_cnn     adamw
# 17  2026-04-21T02:19:40.269426     ablation_lr_01  simple_cnn     adamw
#
#         lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 14  0.0010         128      0.3         none             he    0.9191  ...
# 16  0.0100         128      0.3         none             he    0.9028  ...
# 15  0.0001         128      0.3         none             he    0.8996  ...
# 17  0.1000         128      0.3         none             he    0.6595  ...
#
#     train_time_sec epochs_run  best_epoch  num_params    flops  gpu_mem_mb  \
# 14          116.54         30          26      207018  1293312        50.1
# 16           54.36         14           9      207018  1293312        50.1
# 15          186.08         50          50      207018  1293312        50.1
# 17           50.44         13           8      207018  1293312        50.1
#
#                    device  seed             config_file  slurm_job_id
# 14  NVIDIA A100-SXM4-80GB    42   ablation_lr_0001.yaml      11980587
# 16  NVIDIA A100-SXM4-80GB    42    ablation_lr_001.yaml      11980588
# 15  NVIDIA A100-SXM4-80GB    42  ablation_lr_00001.yaml      11980586
# 17  NVIDIA A100-SXM4-80GB    42     ablation_lr_01.yaml      11980589
#
# [4 rows x 22 columns]

# %%
df[(df["experiment_name"].str.contains("augmentation")) | (df["experiment_name"] == "baseline_simple_cnn")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp                  experiment_name  model_type  \
# 24  2026-04-21T02:39:46.683263              baseline_simple_cnn  simple_cnn
# 2   2026-04-21T01:41:01.180075       ablation_augmentation_none  simple_cnn
# 1   2026-04-21T01:38:15.544820      ablation_augmentation_hflip  simple_cnn
# 0   2026-04-21T01:35:02.124927  ablation_augmentation_crop_flip  simple_cnn
#
#    optimizer     lr  batch_size  dropout augmentation initialization  \
# 24     adamw  0.001         128      0.3         none             he
# 2      adamw  0.001         128      0.3         none             he
# 1      adamw  0.001         128      0.3        hflip             he
# 0      adamw  0.001         128      0.3    crop_flip             he
#
#     accuracy  ...  epochs_run best_epoch  num_params    flops  gpu_mem_mb  \
# 24    0.9191  ...          30         26      207018  1293312        50.1
# 2     0.9191  ...          30         26      207018  1293312        50.1
# 1     0.9176  ...          38         33      207018  1293312        50.1
# 0     0.9070  ...          50         50      207018  1293312        50.1
#
#                    device  seed                           config_file  \
# 24  NVIDIA A100-SXM4-80GB    42              baseline_simple_cnn.yaml
# 2   NVIDIA A100-SXM4-80GB    42       ablation_augmentation_none.yaml
# 1   NVIDIA A100-SXM4-80GB    42      ablation_augmentation_hflip.yaml
# 0   NVIDIA A100-SXM4-80GB    42  ablation_augmentation_crop_flip.yaml
#
#    slurm_job_id   N
# 24     11980596 NaN
# 2      11980574 NaN
# 1      11980573 NaN
# 0      11980572 NaN
#
# [4 rows x 23 columns]

# %%
df[df["experiment_name"].str.contains("batch_size")].sort_values(by="accuracy", ascending=False)
# Out:
#                     timestamp          experiment_name  model_type optimizer  \
# 3  2026-04-21T01:41:27.947499  ablation_batch_size_128  simple_cnn     adamw
# 6  2026-04-21T02:01:50.828457   ablation_batch_size_64  simple_cnn     adamw
# 5  2026-04-21T01:59:19.719530   ablation_batch_size_32  simple_cnn     adamw
# 4  2026-04-21T01:43:31.121645  ablation_batch_size_256  simple_cnn     adamw
#
#       lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 3  0.001         128      0.3         none             he    0.9191  ...
# 6  0.001          64      0.3         none             he    0.9180  ...
# 5  0.001          32      0.3         none             he    0.9170  ...
# 4  0.001         256      0.3         none             he    0.9145  ...
#
#    train_time_sec epochs_run  best_epoch  num_params    flops  gpu_mem_mb  \
# 3          107.86         30          26      207018  1293312        50.1
# 6          106.76         21          16      207018  1293312        45.7
# 5          151.89         23          18      207018  1293312        45.7
# 4           85.08         28          23      207018  1293312        79.4
#
#                   device  seed                   config_file  slurm_job_id
# 3  NVIDIA A100-SXM4-80GB    42  ablation_batch_size_128.yaml      11980575
# 6  NVIDIA A100-SXM4-80GB    42   ablation_batch_size_64.yaml      11980578
# 5  NVIDIA A100-SXM4-80GB    42   ablation_batch_size_32.yaml      11980577
# 4  NVIDIA A100-SXM4-80GB    42  ablation_batch_size_256.yaml      11980576
#
# [4 rows x 22 columns]

# %%
df[df["experiment_name"].str.contains("initialization")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp                  experiment_name  model_type  \
# 13  2026-04-21T02:13:45.706508       ablation_initialization_he  simple_cnn
# 10  2026-04-21T02:11:01.891202  ablation_initialization_default  simple_cnn
# 12  2026-04-21T02:13:27.520313   ablation_initialization_xavier  simple_cnn
#
#    optimizer     lr  batch_size  dropout augmentation initialization  \
# 13     adamw  0.001         128      0.3         none             he
# 10     adamw  0.001         128      0.3         none        default
# 12     adamw  0.001         128      0.3         none         xavier
#
#     accuracy  ...  train_time_sec epochs_run  best_epoch  num_params    flops  \
# 13    0.9191  ...          115.10         30          26      207018  1293312
# 10    0.9182  ...           59.17         15          10      207018  1293312
# 12    0.9160  ...           58.95         16          11      207018  1293312
#
#     gpu_mem_mb                 device  seed  \
# 13        50.1  NVIDIA A100-SXM4-80GB    42
# 10        50.1  NVIDIA A100-SXM4-80GB    42
# 12        50.1  NVIDIA A100-SXM4-80GB    42
#
#                              config_file  slurm_job_id
# 13       ablation_initialization_he.yaml      11980584
# 10  ablation_initialization_default.yaml      11980583
# 12   ablation_initialization_xavier.yaml      11980585
#
# [3 rows x 22 columns]

# %%
df[df["experiment_name"].str.contains("optimizer")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp                  experiment_name  model_type  \
# 18  2026-04-21T02:22:42.443616         ablation_optimizer_adamw  simple_cnn
# 19  2026-04-21T02:25:24.839460          ablation_optimizer_adam  simple_cnn
# 20  2026-04-21T02:29:29.018354  ablation_optimizer_sgd_momentum  simple_cnn
# 21  2026-04-21T02:33:30.188963           ablation_optimizer_sgd  simple_cnn
#
#        optimizer     lr  batch_size  dropout augmentation initialization  \
# 18         adamw  0.001         128      0.3         none             he
# 19          adam  0.001         128      0.3         none             he
# 20  sgd_momentum  0.001         128      0.3         none             he
# 21           sgd  0.001         128      0.3         none             he
#
#     accuracy  ...  train_time_sec epochs_run  best_epoch  num_params    flops  \
# 18    0.9191  ...          115.09         30          26      207018  1293312
# 19    0.9178  ...          128.96         33          28      207018  1293312
# 20    0.8915  ...          189.52         50          49      207018  1293312
# 21    0.8483  ...          187.31         50          50      207018  1293312
#
#     gpu_mem_mb                 device  seed  \
# 18        50.1  NVIDIA A100-SXM4-80GB    42
# 19        50.1  NVIDIA A100-SXM4-80GB    42
# 20        49.3  NVIDIA A100-SXM4-80GB    42
# 21        48.5  NVIDIA A100-SXM4-80GB    42
#
#                              config_file  slurm_job_id
# 18         ablation_optimizer_adamw.yaml      11980590
# 19          ablation_optimizer_adam.yaml      11980591
# 20  ablation_optimizer_sgd_momentum.yaml      11980592
# 21           ablation_optimizer_sgd.yaml      11980593
#
# [4 rows x 22 columns]

# %%
df[(df["experiment_name"].str.contains("dataeff")) & (df["model_type"] == "simple_cnn")].sort_values(by="accuracy", ascending=False)
# Out:
#                      timestamp         experiment_name  model_type optimizer  \
# 32  2026-04-21T06:55:38.931635  dataeff_simple_cnn_50k  simple_cnn     adamw
# 30  2026-04-21T02:48:19.089225  dataeff_simple_cnn_10k  simple_cnn     adamw
# 33  2026-04-21T06:57:17.430289   dataeff_simple_cnn_5k  simple_cnn     adamw
# 31  2026-04-21T02:49:22.926790   dataeff_simple_cnn_1k  simple_cnn     adamw
#
#        lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 32  0.001         128      0.3         none             he    0.9191  ...
# 30  0.001         128      0.3         none             he    0.8710  ...
# 33  0.001         128      0.3         none             he    0.8588  ...
# 31  0.001         128      0.3         none             he    0.7695  ...
#
#     train_time_sec epochs_run  best_epoch  num_params    flops  gpu_mem_mb  \
# 32          103.98         30          26      207018  1293312        50.1
# 30           39.60         28          23      207018  1293312        50.1
# 33           44.13         42          37      207018  1293312        50.1
# 31           29.08         31          26      207018  1293312        50.1
#
#                    device  seed                  config_file  slurm_job_id
# 32  NVIDIA A100-SXM4-80GB    42  dataeff_simple_cnn_50k.yaml      11980604
# 30  NVIDIA A100-SXM4-80GB    42  dataeff_simple_cnn_10k.yaml      11980602
# 33  NVIDIA A100-SXM4-80GB    42   dataeff_simple_cnn_5k.yaml      11980605
# 31  NVIDIA A100-SXM4-80GB    42   dataeff_simple_cnn_1k.yaml      11980603
#
# [4 rows x 22 columns]

# %% [markdown]
# Optimal parameters for Simple CNN:
# - Training size: 50k
# - Augmentation: None
# - Optimizer: adamw
# - Learning Rate: 0.001
# - Batch Size: 128
# - Dropout: 0.3
# - Initialization: he

# %% [markdown]
# # 2. Accuracy vs Dataset Size
#
# Hypothesis: CNN pulls ahead at N>10000 once spatial priors become useful.

# %%
# 2. Extract N from the experiment_name (e.g., 'dataeff_simple_cnn_10k' -> 10000)
def extract_n(name):
    match = re.search(r'(\d+)k', name)
    return int(match.group(1)) * 1000 if match else None

df['N'] = df['experiment_name'].apply(extract_n)

# 3. Clean up: Pivot the data so we have N as index and models as columns
# This handles cases where you might have multiple runs for the same N
plot_df = df.pivot_table(index='N', columns='model_type', values='accuracy')

# 4. Plotting
plt.figure(figsize=(10, 6))
for model in plot_df.columns:
    plt.plot(plot_df.index, plot_df[model], marker='o', label=model)

plt.title('Model Accuracy vs. Training Data Size ($N$)', fontsize=14)
plt.xlabel('Number of Training Samples ($N$)', fontsize=12)
plt.ylabel('Test Accuracy', fontsize=12)
plt.xscale('log') # Recommended since N jumps from 1k to 50k
plt.xticks(plot_df.index, labels=[str(i) for i in plot_df.index])
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# # 3. Accuracy vs FLOPs

# %%
baselines = df[(df["experiment_name"].str.contains("baseline") & (~df["experiment_name"].str.contains("xgboost")))].sort_values(by="accuracy")
baselines
# Out:
#                      timestamp      experiment_name  model_type optimizer  \
# 23  2026-04-21T02:37:02.219750         baseline_mlp         mlp     adamw
# 24  2026-04-21T02:39:46.683263  baseline_simple_cnn  simple_cnn     adamw
# 22  2026-04-21T02:35:25.265091  baseline_deeper_cnn  deeper_cnn     adamw
#
#        lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 23  0.001         128      0.3         none             he    0.8832  ...
# 24  0.001         128      0.3         none             he    0.9191  ...
# 22  0.001         128      0.3         none             he    0.9278  ...
#
#     epochs_run best_epoch  num_params     flops  gpu_mem_mb  \
# 23          19         14      535818    535040        28.6
# 24          30         26      207018   1293312        50.1
# 22          17         12      299114  30313984       163.7
#
#                    device  seed               config_file slurm_job_id   N
# 23  NVIDIA A100-SXM4-80GB    42         baseline_mlp.yaml     11980595 NaN
# 24  NVIDIA A100-SXM4-80GB    42  baseline_simple_cnn.yaml     11980596 NaN
# 22  NVIDIA A100-SXM4-80GB    42  baseline_deeper_cnn.yaml     11980594 NaN
#
# [3 rows x 23 columns]

# %%
def plot_accuracy_vs_flops(df, mode="scatter"):
    """
    Scatter plot: Accuracy vs FLOPs
    Higher is better
    """

    plt.figure(figsize=(12, 7))

    if mode == "scatter":
        for _, row in df.iterrows():
            plt.scatter(
                row['flops'],
                row['accuracy'],
                label=row['model_type'],
                s=80,
                alpha=0.85
            )

            plt.annotate(
                row['model_type'],
                (row['flops'], row['accuracy']),
                textcoords="offset points",
                xytext=(5, 5),
                fontsize=8
            )

        plt.xscale('log')
        plt.title("Accuracy vs Computational Cost (FLOPs)", fontsize=14)
        plt.xlabel("FLOPs (Log Scale)", fontsize=12)
        plt.ylabel("Test Accuracy", fontsize=12)
        plt.grid(True, which="both", ls=":", alpha=0.5)

        # If model names are unique, legend is fine like this
        plt.legend(title="Model Type")

        plt.tight_layout()
        plt.show()

    elif mode == "bar":
        # ---- Accuracy per FLOP ----
        for _, row in baselines.iterrows():
            model = row["model_type"]
            acc = row["accuracy"]
            flops = row["flops"]

            acc_per_flop = acc / flops

            plt.bar(model, acc_per_flop, alpha=0.85)

            plt.text(
                model,
                acc_per_flop,
                f"{acc_per_flop:.2e}",
                ha="center",
                va="bottom",
                fontsize=10
            )

        plt.ylabel("Accuracy / FLOP")
        plt.title("Model Efficiency (Accuracy per FLOP)")
        plt.xticks(rotation=25, ha="right")
        plt.grid(axis="y", alpha=0.3)

    else:
        raise ValueError("mode must be 'scatter' or 'bar'")

    plt.tight_layout()
    plt.show()
plot_accuracy_vs_flops(baselines)
plot_accuracy_vs_flops(baselines, "bar")

# %%
def get_pareto_frontier(df):
    """
    Returns Pareto-optimal points for (flops, accuracy)
    minimizing flops, maximizing accuracy
    """

    # Sort by FLOPs (ascending)
    sorted_df = df.sort_values("flops")

    pareto_points = []
    best_acc = -np.inf

    for _, row in sorted_df.iterrows():
        if row["accuracy"] > best_acc:
            pareto_points.append(row)
            best_acc = row["accuracy"]

    return np.array(pareto_points, dtype=object)

def plot_flops_accuracy_pareto(df):
    plt.figure(figsize=(12, 7))

    # ---- Scatter all models ----
    for _, row in df.iterrows():
        plt.scatter(
            row["flops"],
            row["accuracy"],
            s=80,
            alpha=0.7
        )
        plt.annotate(
            row["model_type"],
            (row["flops"], row["accuracy"]),
            textcoords="offset points",
            xytext=(5, 5),
            fontsize=8
        )

    # ---- Pareto frontier ----
    pareto = df.sort_values("flops")

    pareto_x = []
    pareto_y = []
    best_acc = -np.inf

    for _, row in pareto.iterrows():
        if row["accuracy"] > best_acc:
            pareto_x.append(row["flops"])
            pareto_y.append(row["accuracy"])
            best_acc = row["accuracy"]

    plt.plot(
        pareto_x,
        pareto_y,
        linestyle="--",
        linewidth=2,
        label="Pareto Frontier"
    )

    plt.xscale("log")
    plt.xlabel("FLOPs (Log Scale)")
    plt.ylabel("Accuracy")
    plt.title("Accuracy vs FLOPs with Pareto Frontier")
    plt.grid(True, which="both", ls=":", alpha=0.5)
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_flops_accuracy_pareto(baselines)

# %% [markdown]
# # 4. Accuracy vs Time

# %%
def plot_accuracy_per_epoch_second(df):
    """
    Plot: Accuracy per normalized training time (adjusted for epochs run)
    Higher is better
    """

    plt.figure(figsize=(12, 7))

    for _, row in df.iterrows():
        model = row["model_type"]
        acc = row["accuracy"]
        time = row["train_time_sec"]
        epochs = row["epochs_run"]

        # avoid division issues
        if time == 0 or epochs == 0:
            continue

        acc_per_time = acc * epochs / time

        plt.bar(model, acc_per_time, alpha=0.85)

        plt.text(
            model,
            acc_per_time,
            f"{acc_per_time:.4f}",
            ha="center",
            va="bottom",
            fontsize=10
        )

    plt.ylabel("Accuracy × Epochs / Time")
    plt.title("Model Efficiency (Early-stopping Normalized)")
    plt.xticks(rotation=25, ha="right")
    plt.grid(axis="y", alpha=0.3)

    plt.tight_layout()
    plt.show()

plot_accuracy_per_epoch_second(baselines)

# %%
baselines = df[df["experiment_name"].str.contains("baseline")].sort_values(by="accuracy")
baselines
# Out:
#                      timestamp      experiment_name  model_type optimizer  \
# 23  2026-04-21T02:37:02.219750         baseline_mlp         mlp     adamw
# 25  2026-04-21T02:41:05.832006     baseline_xgboost     xgboost     adamw
# 24  2026-04-21T02:39:46.683263  baseline_simple_cnn  simple_cnn     adamw
# 22  2026-04-21T02:35:25.265091  baseline_deeper_cnn  deeper_cnn     adamw
#
#        lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 23  0.001         128      0.3         none             he    0.8832  ...
# 25  0.001         128      0.3         none             he    0.8911  ...
# 24  0.001         128      0.3         none             he    0.9191  ...
# 22  0.001         128      0.3         none             he    0.9278  ...
#
#     epochs_run best_epoch  num_params     flops  gpu_mem_mb  \
# 23          19         14      535818    535040        28.6
# 25         100         -1          -1        -1         0.0
# 24          30         26      207018   1293312        50.1
# 22          17         12      299114  30313984       163.7
#
#                    device  seed               config_file slurm_job_id   N
# 23  NVIDIA A100-SXM4-80GB    42         baseline_mlp.yaml     11980595 NaN
# 25  NVIDIA A100-SXM4-80GB    42     baseline_xgboost.yaml     11980597 NaN
# 24  NVIDIA A100-SXM4-80GB    42  baseline_simple_cnn.yaml     11980596 NaN
# 22  NVIDIA A100-SXM4-80GB    42  baseline_deeper_cnn.yaml     11980594 NaN
#
# [4 rows x 23 columns]

# %%
def plot_accuracy_vs_clock_time(df, mode="scatter"):
    """
    Scatter plot: Accuracy vs wall clock time
    NOTE: Early stoppage may affect these results
    Higher is better
    """

    plt.figure(figsize=(12, 7))

    if mode == "scatter":
        for _, row in df.iterrows():
            plt.scatter(
                row['train_time_sec'],
                row['accuracy'],
                label=row['model_type'],
                s=80,
                alpha=0.85
            )

            plt.annotate(
                row['model_type'],
                (row['train_time_sec'], row['accuracy']),
                textcoords="offset points",
                xytext=(5, 5),
                fontsize=8
            )

        plt.xscale('log')
        plt.title("Accuracy vs Computational Cost (seconds)", fontsize=14)
        plt.xlabel("Time (seconds)", fontsize=12)
        plt.ylabel("Test Accuracy", fontsize=12)
        plt.grid(True, which="both", ls=":", alpha=0.5)

        # If model names are unique, legend is fine like this
        plt.legend(title="Model Type")

        plt.tight_layout()
        plt.show()

    elif mode == "bar":
        # ---- Accuracy per FLOP ----
        for _, row in baselines.iterrows():
            model = row["model_type"]
            acc = row["accuracy"]
            train_time_sec = row["train_time_sec"]

            acc_per_sec = acc / train_time_sec

            plt.bar(model, acc_per_sec, alpha=0.85)

            plt.text(
                model,
                acc_per_sec,
                f"{acc_per_sec:.2e}",
                ha="center",
                va="bottom",
                fontsize=10
            )

        plt.ylabel("Accuracy / Second")
        plt.title("Model Efficiency (Accuracy per Second)")
        plt.xticks(rotation=25, ha="right")
        plt.grid(axis="y", alpha=0.3)

    else:
        raise ValueError("mode must be 'scatter' or 'bar'")

    plt.tight_layout()
    plt.show()
plot_accuracy_vs_clock_time(baselines)
plot_accuracy_vs_clock_time(baselines, "bar")

# %% [markdown]
# # 5. Per Class Accuracy

# %%
baselines = df[df["experiment_name"].str.contains("baseline")].sort_values(by="accuracy")
baselines
# Out:
#                      timestamp      experiment_name  model_type optimizer  \
# 23  2026-04-21T02:37:02.219750         baseline_mlp         mlp     adamw
# 25  2026-04-21T02:41:05.832006     baseline_xgboost     xgboost     adamw
# 24  2026-04-21T02:39:46.683263  baseline_simple_cnn  simple_cnn     adamw
# 22  2026-04-21T02:35:25.265091  baseline_deeper_cnn  deeper_cnn     adamw
#
#        lr  batch_size  dropout augmentation initialization  accuracy  ...  \
# 23  0.001         128      0.3         none             he    0.8832  ...
# 25  0.001         128      0.3         none             he    0.8911  ...
# 24  0.001         128      0.3         none             he    0.9191  ...
# 22  0.001         128      0.3         none             he    0.9278  ...
#
#     epochs_run best_epoch  num_params     flops  gpu_mem_mb  \
# 23          19         14      535818    535040        28.6
# 25         100         -1          -1        -1         0.0
# 24          30         26      207018   1293312        50.1
# 22          17         12      299114  30313984       163.7
#
#                    device  seed               config_file slurm_job_id   N
# 23  NVIDIA A100-SXM4-80GB    42         baseline_mlp.yaml     11980595 NaN
# 25  NVIDIA A100-SXM4-80GB    42     baseline_xgboost.yaml     11980597 NaN
# 24  NVIDIA A100-SXM4-80GB    42  baseline_simple_cnn.yaml     11980596 NaN
# 22  NVIDIA A100-SXM4-80GB    42  baseline_deeper_cnn.yaml     11980594 NaN
#
# [4 rows x 23 columns]

# %%
import ast
def plot_per_class_f1(baselines):

    class_names = [
        "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
        "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
    ]

    models = baselines["model_type"].tolist()

    # FIX: convert strings → lists of floats
    f1_matrix = np.array([
        ast.literal_eval(row) for row in baselines["f1_per_class"]
    ])

    x = np.arange(len(class_names))
    width = 0.8 / len(models)

    plt.figure(figsize=(14, 6))

    for i, model in enumerate(models):
        plt.bar(
            x + i * width,
            f1_matrix[i],
            width=width,
            label=model
        )

    plt.xticks(
        x + width * (len(models) - 1) / 2,
        class_names,
        rotation=25,
        ha="right"
    )

    plt.ylim(0, 1.0)
    plt.ylabel("F1 Score")
    plt.title("Per-Class F1 Score Across Models")
    plt.grid(axis="y", alpha=0.3)
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_per_class_f1(baselines)

# %% [markdown]
# Trouser/Bag are easy (>0.96 F1), while Shirt/Pullover/Coat/T-shirt are hard (<0.83 F1). The hypothesis that CNNs will
# disproportionately help these confusable classes is testable and interesting.
